# %% [markdown]
# ## Setup

# %%
from evaluate import *
import pandas as pd
from sklearn.model_selection import LeaveOneOut
import warnings
from collections import Counter, defaultdict
from itertools import combinations
import os
import pickle

# %%
data_root = r'RSRM\data\SR\\'

# %%
dataset='s'
regression = True if dataset == 's' else False
cv_info = f'Treated results/{dataset}_folds.txt'
linear_cv_data = f'Treated results/linear_{dataset}_cross_validation.csv'
pysr_cv_data = f'Treated results/pysr_{dataset}_cross_validation.csv'
rsrm_cv_data = f'Treated results/rsrm_{dataset}_cross_validation.csv'
data_file = f'{dataset}'
metric = lambda t, mu: 1 - poisson_deviance(t, mu) / np.sum( t * np.log( (t + 1e-10) / np.mean(t)) )

# %%
folds = read_train_test_indices(cv_info)
dataset_name = {'lepthyphantes': 'canariphantes', 'alestrus': 'alestrus', 's': 'species richness'}[dataset]
dataset_name = dataset_name.capitalize()
if regression:
    metric = 'Pseudo R²'
else:
    metric = 'TSS'
linear_df_o = pd.read_csv(linear_cv_data)
pysr_df_o = pd.read_csv(pysr_cv_data)
rsrm_df_o = pd.read_csv(rsrm_cv_data)
X1, y1 = load_dataset(data_root + data_file + '_train.csv')
X2, y2 = load_dataset(data_root + data_file + '_test.csv')
X = pd.concat([X1, X2], ignore_index=True) 
y = pd.concat([y1, y2], ignore_index=True).astype(int)
get_fold = get_fold_wrapper(X, y, folds)
originals = {'linear': linear_df_o, 'pysr': pysr_df_o, 'rsrm': rsrm_df_o}

# %%
linear_df = pd.DataFrame(columns=['run', 'equation', 'complexity', 'train', 'test'])
pysr_df = pd.DataFrame(columns=['run', 'equation', 'complexity', 'train', 'test'])
rsrm_df = pd.DataFrame(columns=['run', 'equation', 'complexity', 'train', 'test'])
new_ones = {'linear': linear_df, 'pysr': pysr_df, 'rsrm': rsrm_df}
predictions = {}
for key in originals.keys():
    new_df = new_ones[key]
    original_df = originals[key]
    new_df['skeleton'] = original_df['Equation'].apply(replace_numeric_parameters)
    new_df['run'] = original_df['Run']
    new_df['complexity'] = original_df['Equation'].apply(count_weighted_operations)
    new_df.drop(new_df[new_df['complexity'] == 0].index, inplace=True)
    new_df.drop(new_df[new_df['complexity'] > 20].index, inplace=True)
    new_df['equation'] = original_df['Equation']

# %% [markdown]
# # Experiments

# %%
# Try it with (exp, linear): (C = C, C = A, C = 1)
# C is a fittable parameter whereas A is a shape parameter and so is fixed, a constant of nature of sorts
class Parameter:
    def __init__(self, initial_value):
        self.value = initial_value
        self.fitted = None
        self.parameter_set = {1} # Maybe make a subclass with different parameter sets properties/functions but only if it has been fitted
        pass
class FeatureRepr:
    def __init__(self, var_name):
        self.var = var_name
        self.initial_value_C = [1]
        # self.all_fitted_C = []   # All fitted parameters associated to feature, X**C or exp(C*X)
        self.final_C = None
        self.A = None   # Fitted A
    def add_to(self, expression):
        pass
    def log_str(self):
        pass
    def update_initial_value(self, C):
        self.initial_value_C = [C]

class PolyFeatRepr(FeatureRepr):
    def add_to(self, expression):
        expression.add_poly(self)
    def __repr__(self):
        return f'{self.var}**{self.final_C}'
    def __str__(self):
        return f'{self.var}**C'
    def log_str(self):
        return f'C*log({self.var})'

class ExpFeatRepr(FeatureRepr):
    def add_to(self, expression):
        expression.add_exp(self)
    def __repr__(self):
        return f'{self.final_C}**{self.var}'
    def __str__(self):
        return f'exp(C*{self.var})'
    def log_str(self):
        return f'C*{self.var}'

class LogFeatRepr(FeatureRepr):
    def __init__(self, var_name):
        super().__init__(var_name)
        self.initial_value_C = [0,1]
    def add_to(self, expression):
        expression.add_log(self)
    def __repr__(self):
        return f'({self.final_C[0]} + log({self.var}))**{self.final_C[1]}'
    def __str__(self):
        return f'(C+log({self.var}))**C'
    def log_str(self):
        return f'C*log(log({self.var}))'
    def update_initial_value(self, C):
        self.initial_value_C = [0, C]

class ExpressionRepr:
    def __init__(self, feature_list):
        self.expr = {'exp': [], 'poly': [], 'log': []}
        for feat in feature_list:
            feat.add_to(self)            
    def __repr__(self):
        return self.basis_function()
    def add_poly(self, feat):
        self.expr['poly'].append(feat)
    def add_exp(self, feat):
        self.expr['exp'].append(feat)
    def add_log(self, feat):
        self.expr['log'].append(feat)
    def basis_function(self):
        poly_basis = ' * '.join([str(i) for i in self.expr['poly']])
        exp_basis = ' * '.join([str(i) for i in self.expr['exp']])
        log_basis = ' * '.join([str(i) for i in self.expr['log']])
        non_empty_basiss = [i for i in [poly_basis, exp_basis, log_basis] if i]
        basis = ' * '.join(non_empty_basiss)
        return basis
    def log_basis_function(self):
        poly_basis = ' * '.join([str(i) for i in self.expr['poly']])
        exp_basis = ' * '.join([str(i) for i in self.expr['exp']])
        log_basis = ' * '.join([str(i) for i in self.expr['log']])
        non_empty_basiss = [i for i in [poly_basis, exp_basis, log_basis] if i]
        basis = ' * '.join(non_empty_basiss)
        return basis

# %%
from itertools import combinations
from copy import deepcopy
basinhop = True
variables = X.columns.tolist()
res2 = []
all_single_features = [PolyFeatRepr(var) for var in variables] + [ExpFeatRepr(var) for var in variables] + [LogFeatRepr(var) for var in variables]
all_feature_combinations = [feature_comb for num_feats in range(1,4) for feature_comb in combinations(all_single_features, num_feats)]
all_feature_combinations = [[deepcopy(feat) for feat in feature_comb] for feature_comb in all_feature_combinations]
all_expressions = [ExpressionRepr(feature_comb) for feature_comb in all_feature_combinations]
all_expressions
# Out:
# [H**C,
#  Sl**C,
#  P**C,
#  T**C,
#  D**C,
#  exp(C*H),
#  exp(C*Sl),
#  exp(C*P),
#  exp(C*T),
#  exp(C*D),
#  (C+log(H))**C,
#  (C+log(Sl))**C,
#  (C+log(P))**C,
#  (C+log(T))**C,
#  (C+log(D))**C,
#  H**C * Sl**C,
#  H**C * P**C,
#  H**C * T**C,
#  H**C * D**C,
#  H**C * exp(C*H),
#  H**C * exp(C*Sl),
#  H**C * exp(C*P),
#  H**C * exp(C*T),
#  H**C * exp(C*D),
#  H**C * (C+log(H))**C,
#  H**C * (C+log(Sl))**C,
#  H**C * (C+log(P))**C,
#  H**C * (C+log(T))**C,
#  H**C * (C+log(D))**C,
#  Sl**C * P**C,
#  Sl**C * T**C,
#  Sl**C * D**C,
#  Sl**C * exp(C*H),
#  Sl**C * exp(C*Sl),
#  Sl**C * exp(C*P),
#  Sl**C * exp(C*T),
#  Sl**C * exp(C*D),
#  Sl**C * (C+log(H))**C,
#  Sl**C * (C+log(Sl))**C,
#  Sl**C * (C+log(P))**C,
#  Sl**C * (C+log(T))**C,
#  Sl**C * (C+log(D))**C,
#  P**C * T**C,
#  P**C * D**C,
#  P**C * exp(C*H),
#  P**C * exp(C*Sl),
#  P**C * exp(C*P),
#  P**C * exp(C*T),
#  P**C * exp(C*D),
#  P**C * (C+log(H))**C,
#  P**C * (C+log(Sl))**C,
#  P**C * (C+log(P))**C,
#  P**C * (C+log(T))**C,
#  P**C * (C+log(D))**C,
#  T**C * D**C,
#  T**C * exp(C*H),
#  T**C * exp(C*Sl),
#  T**C * exp(C*P),
#  T**C * exp(C*T),
#  T**C * exp(C*D),
#  T**C * (C+log(H))**C,
#  T**C * (C+log(Sl))**C,
#  T**C * (C+log(P))**C,
#  T**C * (C+log(T))**C,
#  T**C * (C+log(D))**C,
#  D**C * exp(C*H),
#  D**C * exp(C*Sl),
#  D**C * exp(C*P),
#  D**C * exp(C*T),
#  D**C * exp(C*D),
#  D**C * (C+log(H))**C,
#  D**C * (C+log(Sl))**C,
#  D**C * (C+log(P))**C,
#  D**C * (C+log(T))**C,
#  D**C * (C+log(D))**C,
#  exp(C*H) * exp(C*Sl),
#  exp(C*H) * exp(C*P),
#  exp(C*H) * exp(C*T),
#  exp(C*H) * exp(C*D),
#  exp(C*H) * (C+log(H))**C,
#  exp(C*H) * (C+log(Sl))**C,
#  exp(C*H) * (C+log(P))**C,
#  exp(C*H) * (C+log(T))**C,
#  exp(C*H) * (C+log(D))**C,
#  exp(C*Sl) * exp(C*P),
#  exp(C*Sl) * exp(C*T),
#  exp(C*Sl) * exp(C*D),
#  exp(C*Sl) * (C+log(H))**C,
#  exp(C*Sl) * (C+log(Sl))**C,
#  exp(C*Sl) * (C+log(P))**C,
#  exp(C*Sl) * (C+log(T))**C,
#  exp(C*Sl) * (C+log(D))**C,
#  exp(C*P) * exp(C*T),
#  exp(C*P) * exp(C*D),
#  exp(C*P) * (C+log(H))**C,
#  exp(C*P) * (C+log(Sl))**C,
#  exp(C*P) * (C+log(P))**C,
#  exp(C*P) * (C+log(T))**C,
#  exp(C*P) * (C+log(D))**C,
#  exp(C*T) * exp(C*D),
#  exp(C*T) * (C+log(H))**C,
#  exp(C*T) * (C+log(Sl))**C,
#  exp(C*T) * (C+log(P))**C,
#  exp(C*T) * (C+log(T))**C,
#  exp(C*T) * (C+log(D))**C,
#  exp(C*D) * (C+log(H))**C,
#  exp(C*D) * (C+log(Sl))**C,
#  exp(C*D) * (C+log(P))**C,
#  exp(C*D) * (C+log(T))**C,
#  exp(C*D) * (C+log(D))**C,
#  (C+log(H))**C * (C+log(Sl))**C,
#  (C+log(H))**C * (C+log(P))**C,
#  (C+log(H))**C * (C+log(T))**C,
#  (C+log(H))**C * (C+log(D))**C,
#  (C+log(Sl))**C * (C+log(P))**C,
#  (C+log(Sl))**C * (C+log(T))**C,
#  (C+log(Sl))**C * (C+log(D))**C,
#  (C+log(P))**C * (C+log(T))**C,
#  (C+log(P))**C * (C+log(D))**C,
#  (C+log(T))**C * (C+log(D))**C,
#  H**C * Sl**C * P**C,
#  H**C * Sl**C * T**C,
#  H**C * Sl**C * D**C,
#  H**C * Sl**C * exp(C*H),
#  H**C * Sl**C * exp(C*Sl),
#  H**C * Sl**C * exp(C*P),
#  H**C * Sl**C * exp(C*T),
#  H**C * Sl**C * exp(C*D),
#  H**C * Sl**C * (C+log(H))**C,
#  H**C * Sl**C * (C+log(Sl))**C,
#  H**C * Sl**C * (C+log(P))**C,
#  H**C * Sl**C * (C+log(T))**C,
#  H**C * Sl**C * (C+log(D))**C,
#  H**C * P**C * T**C,
#  H**C * P**C * D**C,
#  H**C * P**C * exp(C*H),
#  H**C * P**C * exp(C*Sl),
#  H**C * P**C * exp(C*P),
#  H**C * P**C * exp(C*T),
#  H**C * P**C * exp(C*D),
#  H**C * P**C * (C+log(H))**C,
#  H**C * P**C * (C+log(Sl))**C,
#  H**C * P**C * (C+log(P))**C,
#  H**C * P**C * (C+log(T))**C,
#  H**C * P**C * (C+log(D))**C,
#  H**C * T**C * D**C,
#  H**C * T**C * exp(C*H),
#  H**C * T**C * exp(C*Sl),
#  H**C * T**C * exp(C*P),
#  H**C * T**C * exp(C*T),
#  H**C * T**C * exp(C*D),
#  H**C * T**C * (C+log(H))**C,
#  H**C * T**C * (C+log(Sl))**C,
#  H**C * T**C * (C+log(P))**C,
#  H**C * T**C * (C+log(T))**C,
#  H**C * T**C * (C+log(D))**C,
#  H**C * D**C * exp(C*H),
#  H**C * D**C * exp(C*Sl),
#  H**C * D**C * exp(C*P),
#  H**C * D**C * exp(C*T),
#  H**C * D**C * exp(C*D),
#  H**C * D**C * (C+log(H))**C,
#  H**C * D**C * (C+log(Sl))**C,
#  H**C * D**C * (C+log(P))**C,
#  H**C * D**C * (C+log(T))**C,
#  H**C * D**C * (C+log(D))**C,
#  H**C * exp(C*H) * exp(C*Sl),
#  H**C * exp(C*H) * exp(C*P),
#  H**C * exp(C*H) * exp(C*T),
#  H**C * exp(C*H) * exp(C*D),
#  H**C * exp(C*H) * (C+log(H))**C,
#  H**C * exp(C*H) * (C+log(Sl))**C,
#  H**C * exp(C*H) * (C+log(P))**C,
#  H**C * exp(C*H) * (C+log(T))**C,
#  H**C * exp(C*H) * (C+log(D))**C,
#  H**C * exp(C*Sl) * exp(C*P),
#  H**C * exp(C*Sl) * exp(C*T),
#  H**C * exp(C*Sl) * exp(C*D),
#  H**C * exp(C*Sl) * (C+log(H))**C,
#  H**C * exp(C*Sl) * (C+log(Sl))**C,
#  H**C * exp(C*Sl) * (C+log(P))**C,
#  H**C * exp(C*Sl) * (C+log(T))**C,
#  H**C * exp(C*Sl) * (C+log(D))**C,
#  H**C * exp(C*P) * exp(C*T),
#  H**C * exp(C*P) * exp(C*D),
#  H**C * exp(C*P) * (C+log(H))**C,
#  H**C * exp(C*P) * (C+log(Sl))**C,
#  H**C * exp(C*P) * (C+log(P))**C,
#  H**C * exp(C*P) * (C+log(T))**C,
#  H**C * exp(C*P) * (C+log(D))**C,
#  H**C * exp(C*T) * exp(C*D),
#  H**C * exp(C*T) * (C+log(H))**C,
#  H**C * exp(C*T) * (C+log(Sl))**C,
#  H**C * exp(C*T) * (C+log(P))**C,
#  H**C * exp(C*T) * (C+log(T))**C,
#  H**C * exp(C*T) * (C+log(D))**C,
#  H**C * exp(C*D) * (C+log(H))**C,
#  H**C * exp(C*D) * (C+log(Sl))**C,
#  H**C * exp(C*D) * (C+log(P))**C,
#  H**C * exp(C*D) * (C+log(T))**C,
#  H**C * exp(C*D) * (C+log(D))**C,
#  H**C * (C+log(H))**C * (C+log(Sl))**C,
#  H**C * (C+log(H))**C * (C+log(P))**C,
#  H**C * (C+log(H))**C * (C+log(T))**C,
#  H**C * (C+log(H))**C * (C+log(D))**C,
#  H**C * (C+log(Sl))**C * (C+log(P))**C,
#  H**C * (C+log(Sl))**C * (C+log(T))**C,
#  H**C * (C+log(Sl))**C * (C+log(D))**C,
#  H**C * (C+log(P))**C * (C+log(T))**C,
#  H**C * (C+log(P))**C * (C+log(D))**C,
#  H**C * (C+log(T))**C * (C+log(D))**C,
#  Sl**C * P**C * T**C,
#  Sl**C * P**C * D**C,
#  Sl**C * P**C * exp(C*H),
#  Sl**C * P**C * exp(C*Sl),
#  Sl**C * P**C * exp(C*P),
#  Sl**C * P**C * exp(C*T),
#  Sl**C * P**C * exp(C*D),
#  Sl**C * P**C * (C+log(H))**C,
#  Sl**C * P**C * (C+log(Sl))**C,
#  Sl**C * P**C * (C+log(P))**C,
#  Sl**C * P**C * (C+log(T))**C,
#  Sl**C * P**C * (C+log(D))**C,
#  Sl**C * T**C * D**C,
#  Sl**C * T**C * exp(C*H),
#  Sl**C * T**C * exp(C*Sl),
#  Sl**C * T**C * exp(C*P),
#  Sl**C * T**C * exp(C*T),
#  Sl**C * T**C * exp(C*D),
#  Sl**C * T**C * (C+log(H))**C,
#  Sl**C * T**C * (C+log(Sl))**C,
#  Sl**C * T**C * (C+log(P))**C,
#  Sl**C * T**C * (C+log(T))**C,
#  Sl**C * T**C * (C+log(D))**C,
#  Sl**C * D**C * exp(C*H),
#  Sl**C * D**C * exp(C*Sl),
#  Sl**C * D**C * exp(C*P),
#  Sl**C * D**C * exp(C*T),
#  Sl**C * D**C * exp(C*D),
#  Sl**C * D**C * (C+log(H))**C,
#  Sl**C * D**C * (C+log(Sl))**C,
#  Sl**C * D**C * (C+log(P))**C,
#  Sl**C * D**C * (C+log(T))**C,
#  Sl**C * D**C * (C+log(D))**C,
#  Sl**C * exp(C*H) * exp(C*Sl),
#  Sl**C * exp(C*H) * exp(C*P),
#  Sl**C * exp(C*H) * exp(C*T),
#  Sl**C * exp(C*H) * exp(C*D),
#  Sl**C * exp(C*H) * (C+log(H))**C,
#  Sl**C * exp(C*H) * (C+log(Sl))**C,
#  Sl**C * exp(C*H) * (C+log(P))**C,
#  Sl**C * exp(C*H) * (C+log(T))**C,
#  Sl**C * exp(C*H) * (C+log(D))**C,
#  Sl**C * exp(C*Sl) * exp(C*P),
#  Sl**C * exp(C*Sl) * exp(C*T),
#  Sl**C * exp(C*Sl) * exp(C*D),
#  Sl**C * exp(C*Sl) * (C+log(H))**C,
#  Sl**C * exp(C*Sl) * (C+log(Sl))**C,
#  Sl**C * exp(C*Sl) * (C+log(P))**C,
#  Sl**C * exp(C*Sl) * (C+log(T))**C,
#  Sl**C * exp(C*Sl) * (C+log(D))**C,
#  Sl**C * exp(C*P) * exp(C*T),
#  Sl**C * exp(C*P) * exp(C*D),
#  Sl**C * exp(C*P) * (C+log(H))**C,
#  Sl**C * exp(C*P) * (C+log(Sl))**C,
#  Sl**C * exp(C*P) * (C+log(P))**C,
#  Sl**C * exp(C*P) * (C+log(T))**C,
#  Sl**C * exp(C*P) * (C+log(D))**C,
#  Sl**C * exp(C*T) * exp(C*D),
#  Sl**C * exp(C*T) * (C+log(H))**C,
#  Sl**C * exp(C*T) * (C+log(Sl))**C,
#  Sl**C * exp(C*T) * (C+log(P))**C,
#  Sl**C * exp(C*T) * (C+log(T))**C,
#  Sl**C * exp(C*T) * (C+log(D))**C,
#  Sl**C * exp(C*D) * (C+log(H))**C,
#  Sl**C * exp(C*D) * (C+log(Sl))**C,
#  Sl**C * exp(C*D) * (C+log(P))**C,
#  Sl**C * exp(C*D) * (C+log(T))**C,
#  Sl**C * exp(C*D) * (C+log(D))**C,
#  Sl**C * (C+log(H))**C * (C+log(Sl))**C,
#  Sl**C * (C+log(H))**C * (C+log(P))**C,
#  Sl**C * (C+log(H))**C * (C+log(T))**C,
#  Sl**C * (C+log(H))**C * (C+log(D))**C,
#  Sl**C * (C+log(Sl))**C * (C+log(P))**C,
#  Sl**C * (C+log(Sl))**C * (C+log(T))**C,
#  Sl**C * (C+log(Sl))**C * (C+log(D))**C,
#  Sl**C * (C+log(P))**C * (C+log(T))**C,
#  Sl**C * (C+log(P))**C * (C+log(D))**C,
#  Sl**C * (C+log(T))**C * (C+log(D))**C,
#  P**C * T**C * D**C,
#  P**C * T**C * exp(C*H),
#  P**C * T**C * exp(C*Sl),
#  P**C * T**C * exp(C*P),
#  P**C * T**C * exp(C*T),
#  P**C * T**C * exp(C*D),
#  P**C * T**C * (C+log(H))**C,
#  P**C * T**C * (C+log(Sl))**C,
#  P**C * T**C * (C+log(P))**C,
#  P**C * T**C * (C+log(T))**C,
#  P**C * T**C * (C+log(D))**C,
#  P**C * D**C * exp(C*H),
#  P**C * D**C * exp(C*Sl),
#  P**C * D**C * exp(C*P),
#  P**C * D**C * exp(C*T),
#  P**C * D**C * exp(C*D),
#  P**C * D**C * (C+log(H))**C,
#  P**C * D**C * (C+log(Sl))**C,
#  P**C * D**C * (C+log(P))**C,
#  P**C * D**C * (C+log(T))**C,
#  P**C * D**C * (C+log(D))**C,
#  P**C * exp(C*H) * exp(C*Sl),
#  P**C * exp(C*H) * exp(C*P),
#  P**C * exp(C*H) * exp(C*T),
#  P**C * exp(C*H) * exp(C*D),
#  P**C * exp(C*H) * (C+log(H))**C,
#  P**C * exp(C*H) * (C+log(Sl))**C,
#  P**C * exp(C*H) * (C+log(P))**C,
#  P**C * exp(C*H) * (C+log(T))**C,
#  P**C * exp(C*H) * (C+log(D))**C,
#  P**C * exp(C*Sl) * exp(C*P),
#  P**C * exp(C*Sl) * exp(C*T),
#  P**C * exp(C*Sl) * exp(C*D),
#  P**C * exp(C*Sl) * (C+log(H))**C,
#  P**C * exp(C*Sl) * (C+log(Sl))**C,
#  P**C * exp(C*Sl) * (C+log(P))**C,
#  P**C * exp(C*Sl) * (C+log(T))**C,
#  P**C * exp(C*Sl) * (C+log(D))**C,
#  P**C * exp(C*P) * exp(C*T),
#  P**C * exp(C*P) * exp(C*D),
#  P**C * exp(C*P) * (C+log(H))**C,
#  P**C * exp(C*P) * (C+log(Sl))**C,
#  P**C * exp(C*P) * (C+log(P))**C,
#  P**C * exp(C*P) * (C+log(T))**C,
#  P**C * exp(C*P) * (C+log(D))**C,
#  P**C * exp(C*T) * exp(C*D),
#  P**C * exp(C*T) * (C+log(H))**C,
#  P**C * exp(C*T) * (C+log(Sl))**C,
#  P**C * exp(C*T) * (C+log(P))**C,
#  P**C * exp(C*T) * (C+log(T))**C,
#  P**C * exp(C*T) * (C+log(D))**C,
#  P**C * exp(C*D) * (C+log(H))**C,
#  P**C * exp(C*D) * (C+log(Sl))**C,
#  P**C * exp(C*D) * (C+log(P))**C,
#  P**C * exp(C*D) * (C+log(T))**C,
#  P**C * exp(C*D) * (C+log(D))**C,
#  P**C * (C+log(H))**C * (C+log(Sl))**C,
#  P**C * (C+log(H))**C * (C+log(P))**C,
#  P**C * (C+log(H))**C * (C+log(T))**C,
#  P**C * (C+log(H))**C * (C+log(D))**C,
#  P**C * (C+log(Sl))**C * (C+log(P))**C,
#  P**C * (C+log(Sl))**C * (C+log(T))**C,
#  P**C * (C+log(Sl))**C * (C+log(D))**C,
#  P**C * (C+log(P))**C * (C+log(T))**C,
#  P**C * (C+log(P))**C * (C+log(D))**C,
#  P**C * (C+log(T))**C * (C+log(D))**C,
#  T**C * D**C * exp(C*H),
#  T**C * D**C * exp(C*Sl),
#  T**C * D**C * exp(C*P),
#  T**C * D**C * exp(C*T),
#  T**C * D**C * exp(C*D),
#  T**C * D**C * (C+log(H))**C,
#  T**C * D**C * (C+log(Sl))**C,
#  T**C * D**C * (C+log(P))**C,
#  T**C * D**C * (C+log(T))**C,
#  T**C * D**C * (C+log(D))**C,
#  T**C * exp(C*H) * exp(C*Sl),
#  T**C * exp(C*H) * exp(C*P),
#  T**C * exp(C*H) * exp(C*T),
#  T**C * exp(C*H) * exp(C*D),
#  T**C * exp(C*H) * (C+log(H))**C,
#  T**C * exp(C*H) * (C+log(Sl))**C,
#  T**C * exp(C*H) * (C+log(P))**C,
#  T**C * exp(C*H) * (C+log(T))**C,
#  T**C * exp(C*H) * (C+log(D))**C,
#  T**C * exp(C*Sl) * exp(C*P),
#  T**C * exp(C*Sl) * exp(C*T),
#  T**C * exp(C*Sl) * exp(C*D),
#  T**C * exp(C*Sl) * (C+log(H))**C,
#  T**C * exp(C*Sl) * (C+log(Sl))**C,
#  T**C * exp(C*Sl) * (C+log(P))**C,
#  T**C * exp(C*Sl) * (C+log(T))**C,
#  T**C * exp(C*Sl) * (C+log(D))**C,
#  T**C * exp(C*P) * exp(C*T),
#  T**C * exp(C*P) * exp(C*D),
#  T**C * exp(C*P) * (C+log(H))**C,
#  T**C * exp(C*P) * (C+log(Sl))**C,
#  T**C * exp(C*P) * (C+log(P))**C,
#  T**C * exp(C*P) * (C+log(T))**C,
#  T**C * exp(C*P) * (C+log(D))**C,
#  T**C * exp(C*T) * exp(C*D),
#  T**C * exp(C*T) * (C+log(H))**C,
#  T**C * exp(C*T) * (C+log(Sl))**C,
#  T**C * exp(C*T) * (C+log(P))**C,
#  T**C * exp(C*T) * (C+log(T))**C,
#  T**C * exp(C*T) * (C+log(D))**C,
#  T**C * exp(C*D) * (C+log(H))**C,
#  T**C * exp(C*D) * (C+log(Sl))**C,
#  T**C * exp(C*D) * (C+log(P))**C,
#  T**C * exp(C*D) * (C+log(T))**C,
#  T**C * exp(C*D) * (C+log(D))**C,
#  T**C * (C+log(H))**C * (C+log(Sl))**C,
#  T**C * (C+log(H))**C * (C+log(P))**C,
#  T**C * (C+log(H))**C * (C+log(T))**C,
#  T**C * (C+log(H))**C * (C+log(D))**C,
#  T**C * (C+log(Sl))**C * (C+log(P))**C,
#  T**C * (C+log(Sl))**C * (C+log(T))**C,
#  T**C * (C+log(Sl))**C * (C+log(D))**C,
#  T**C * (C+log(P))**C * (C+log(T))**C,
#  T**C * (C+log(P))**C * (C+log(D))**C,
#  T**C * (C+log(T))**C * (C+log(D))**C,
#  D**C * exp(C*H) * exp(C*Sl),
#  D**C * exp(C*H) * exp(C*P),
#  D**C * exp(C*H) * exp(C*T),
#  D**C * exp(C*H) * exp(C*D),
#  D**C * exp(C*H) * (C+log(H))**C,
#  D**C * exp(C*H) * (C+log(Sl))**C,
#  D**C * exp(C*H) * (C+log(P))**C,
#  D**C * exp(C*H) * (C+log(T))**C,
#  D**C * exp(C*H) * (C+log(D))**C,
#  D**C * exp(C*Sl) * exp(C*P),
#  D**C * exp(C*Sl) * exp(C*T),
#  D**C * exp(C*Sl) * exp(C*D),
#  D**C * exp(C*Sl) * (C+log(H))**C,
#  D**C * exp(C*Sl) * (C+log(Sl))**C,
#  D**C * exp(C*Sl) * (C+log(P))**C,
#  D**C * exp(C*Sl) * (C+log(T))**C,
#  D**C * exp(C*Sl) * (C+log(D))**C,
#  D**C * exp(C*P) * exp(C*T),
#  D**C * exp(C*P) * exp(C*D),
#  D**C * exp(C*P) * (C+log(H))**C,
#  D**C * exp(C*P) * (C+log(Sl))**C,
#  D**C * exp(C*P) * (C+log(P))**C,
#  D**C * exp(C*P) * (C+log(T))**C,
#  D**C * exp(C*P) * (C+log(D))**C,
#  D**C * exp(C*T) * exp(C*D),
#  D**C * exp(C*T) * (C+log(H))**C,
#  D**C * exp(C*T) * (C+log(Sl))**C,
#  D**C * exp(C*T) * (C+log(P))**C,
#  D**C * exp(C*T) * (C+log(T))**C,
#  D**C * exp(C*T) * (C+log(D))**C,
#  D**C * exp(C*D) * (C+log(H))**C,
#  D**C * exp(C*D) * (C+log(Sl))**C,
#  D**C * exp(C*D) * (C+log(P))**C,
#  D**C * exp(C*D) * (C+log(T))**C,
#  D**C * exp(C*D) * (C+log(D))**C,
#  D**C * (C+log(H))**C * (C+log(Sl))**C,
#  D**C * (C+log(H))**C * (C+log(P))**C,
#  D**C * (C+log(H))**C * (C+log(T))**C,
#  D**C * (C+log(H))**C * (C+log(D))**C,
#  D**C * (C+log(Sl))**C * (C+log(P))**C,
#  D**C * (C+log(Sl))**C * (C+log(T))**C,
#  D**C * (C+log(Sl))**C * (C+log(D))**C,
#  D**C * (C+log(P))**C * (C+log(T))**C,
#  D**C * (C+log(P))**C * (C+log(D))**C,
#  D**C * (C+log(T))**C * (C+log(D))**C,
#  exp(C*H) * exp(C*Sl) * exp(C*P),
#  exp(C*H) * exp(C*Sl) * exp(C*T),
#  exp(C*H) * exp(C*Sl) * exp(C*D),
#  exp(C*H) * exp(C*Sl) * (C+log(H))**C,
#  exp(C*H) * exp(C*Sl) * (C+log(Sl))**C,
#  exp(C*H) * exp(C*Sl) * (C+log(P))**C,
#  exp(C*H) * exp(C*Sl) * (C+log(T))**C,
#  exp(C*H) * exp(C*Sl) * (C+log(D))**C,
#  exp(C*H) * exp(C*P) * exp(C*T),
#  exp(C*H) * exp(C*P) * exp(C*D),
#  exp(C*H) * exp(C*P) * (C+log(H))**C,
#  exp(C*H) * exp(C*P) * (C+log(Sl))**C,
#  exp(C*H) * exp(C*P) * (C+log(P))**C,
#  exp(C*H) * exp(C*P) * (C+log(T))**C,
#  exp(C*H) * exp(C*P) * (C+log(D))**C,
#  exp(C*H) * exp(C*T) * exp(C*D),
#  exp(C*H) * exp(C*T) * (C+log(H))**C,
#  exp(C*H) * exp(C*T) * (C+log(Sl))**C,
#  exp(C*H) * exp(C*T) * (C+log(P))**C,
#  exp(C*H) * exp(C*T) * (C+log(T))**C,
#  exp(C*H) * exp(C*T) * (C+log(D))**C,
#  exp(C*H) * exp(C*D) * (C+log(H))**C,
#  exp(C*H) * exp(C*D) * (C+log(Sl))**C,
#  exp(C*H) * exp(C*D) * (C+log(P))**C,
#  exp(C*H) * exp(C*D) * (C+log(T))**C,
#  exp(C*H) * exp(C*D) * (C+log(D))**C,
#  exp(C*H) * (C+log(H))**C * (C+log(Sl))**C,
#  exp(C*H) * (C+log(H))**C * (C+log(P))**C,
#  exp(C*H) * (C+log(H))**C * (C+log(T))**C,
#  exp(C*H) * (C+log(H))**C * (C+log(D))**C,
#  exp(C*H) * (C+log(Sl))**C * (C+log(P))**C,
#  exp(C*H) * (C+log(Sl))**C * (C+log(T))**C,
#  exp(C*H) * (C+log(Sl))**C * (C+log(D))**C,
#  exp(C*H) * (C+log(P))**C * (C+log(T))**C,
#  exp(C*H) * (C+log(P))**C * (C+log(D))**C,
#  exp(C*H) * (C+log(T))**C * (C+log(D))**C,
#  exp(C*Sl) * exp(C*P) * exp(C*T),
#  exp(C*Sl) * exp(C*P) * exp(C*D),
#  exp(C*Sl) * exp(C*P) * (C+log(H))**C,
#  exp(C*Sl) * exp(C*P) * (C+log(Sl))**C,
#  exp(C*Sl) * exp(C*P) * (C+log(P))**C,
#  exp(C*Sl) * exp(C*P) * (C+log(T))**C,
#  exp(C*Sl) * exp(C*P) * (C+log(D))**C,
#  exp(C*Sl) * exp(C*T) * exp(C*D),
#  exp(C*Sl) * exp(C*T) * (C+log(H))**C,
#  exp(C*Sl) * exp(C*T) * (C+log(Sl))**C,
#  exp(C*Sl) * exp(C*T) * (C+log(P))**C,
#  exp(C*Sl) * exp(C*T) * (C+log(T))**C,
#  exp(C*Sl) * exp(C*T) * (C+log(D))**C,
#  exp(C*Sl) * exp(C*D) * (C+log(H))**C,
#  exp(C*Sl) * exp(C*D) * (C+log(Sl))**C,
#  exp(C*Sl) * exp(C*D) * (C+log(P))**C,
#  exp(C*Sl) * exp(C*D) * (C+log(T))**C,
#  exp(C*Sl) * exp(C*D) * (C+log(D))**C,
#  exp(C*Sl) * (C+log(H))**C * (C+log(Sl))**C,
#  exp(C*Sl) * (C+log(H))**C * (C+log(P))**C,
#  exp(C*Sl) * (C+log(H))**C * (C+log(T))**C,
#  exp(C*Sl) * (C+log(H))**C * (C+log(D))**C,
#  exp(C*Sl) * (C+log(Sl))**C * (C+log(P))**C,
#  exp(C*Sl) * (C+log(Sl))**C * (C+log(T))**C,
#  exp(C*Sl) * (C+log(Sl))**C * (C+log(D))**C,
#  exp(C*Sl) * (C+log(P))**C * (C+log(T))**C,
#  exp(C*Sl) * (C+log(P))**C * (C+log(D))**C,
#  exp(C*Sl) * (C+log(T))**C * (C+log(D))**C,
#  exp(C*P) * exp(C*T) * exp(C*D),
#  exp(C*P) * exp(C*T) * (C+log(H))**C,
#  exp(C*P) * exp(C*T) * (C+log(Sl))**C,
#  exp(C*P) * exp(C*T) * (C+log(P))**C,
#  exp(C*P) * exp(C*T) * (C+log(T))**C,
#  exp(C*P) * exp(C*T) * (C+log(D))**C,
#  exp(C*P) * exp(C*D) * (C+log(H))**C,
#  exp(C*P) * exp(C*D) * (C+log(Sl))**C,
#  exp(C*P) * exp(C*D) * (C+log(P))**C,
#  exp(C*P) * exp(C*D) * (C+log(T))**C,
#  exp(C*P) * exp(C*D) * (C+log(D))**C,
#  exp(C*P) * (C+log(H))**C * (C+log(Sl))**C,
#  exp(C*P) * (C+log(H))**C * (C+log(P))**C,
#  exp(C*P) * (C+log(H))**C * (C+log(T))**C,
#  exp(C*P) * (C+log(H))**C * (C+log(D))**C,
#  exp(C*P) * (C+log(Sl))**C * (C+log(P))**C,
#  exp(C*P) * (C+log(Sl))**C * (C+log(T))**C,
#  exp(C*P) * (C+log(Sl))**C * (C+log(D))**C,
#  exp(C*P) * (C+log(P))**C * (C+log(T))**C,
#  exp(C*P) * (C+log(P))**C * (C+log(D))**C,
#  exp(C*P) * (C+log(T))**C * (C+log(D))**C,
#  exp(C*T) * exp(C*D) * (C+log(H))**C,
#  exp(C*T) * exp(C*D) * (C+log(Sl))**C,
#  exp(C*T) * exp(C*D) * (C+log(P))**C,
#  exp(C*T) * exp(C*D) * (C+log(T))**C,
#  exp(C*T) * exp(C*D) * (C+log(D))**C,
#  exp(C*T) * (C+log(H))**C * (C+log(Sl))**C,
#  exp(C*T) * (C+log(H))**C * (C+log(P))**C,
#  exp(C*T) * (C+log(H))**C * (C+log(T))**C,
#  exp(C*T) * (C+log(H))**C * (C+log(D))**C,
#  exp(C*T) * (C+log(Sl))**C * (C+log(P))**C,
#  exp(C*T) * (C+log(Sl))**C * (C+log(T))**C,
#  exp(C*T) * (C+log(Sl))**C * (C+log(D))**C,
#  exp(C*T) * (C+log(P))**C * (C+log(T))**C,
#  exp(C*T) * (C+log(P))**C * (C+log(D))**C,
#  exp(C*T) * (C+log(T))**C * (C+log(D))**C,
#  exp(C*D) * (C+log(H))**C * (C+log(Sl))**C,
#  exp(C*D) * (C+log(H))**C * (C+log(P))**C,
#  exp(C*D) * (C+log(H))**C * (C+log(T))**C,
#  exp(C*D) * (C+log(H))**C * (C+log(D))**C,
#  exp(C*D) * (C+log(Sl))**C * (C+log(P))**C,
#  exp(C*D) * (C+log(Sl))**C * (C+log(T))**C,
#  exp(C*D) * (C+log(Sl))**C * (C+log(D))**C,
#  exp(C*D) * (C+log(P))**C * (C+log(T))**C,
#  exp(C*D) * (C+log(P))**C * (C+log(D))**C,
#  exp(C*D) * (C+log(T))**C * (C+log(D))**C,
#  (C+log(H))**C * (C+log(Sl))**C * (C+log(P))**C,
#  (C+log(H))**C * (C+log(Sl))**C * (C+log(T))**C,
#  (C+log(H))**C * (C+log(Sl))**C * (C+log(D))**C,
#  (C+log(H))**C * (C+log(P))**C * (C+log(T))**C,
#  (C+log(H))**C * (C+log(P))**C * (C+log(D))**C,
#  (C+log(H))**C * (C+log(T))**C * (C+log(D))**C,
#  (C+log(Sl))**C * (C+log(P))**C * (C+log(T))**C,
#  (C+log(Sl))**C * (C+log(P))**C * (C+log(D))**C,
#  (C+log(Sl))**C * (C+log(T))**C * (C+log(D))**C,
#  (C+log(P))**C * (C+log(T))**C * (C+log(D))**C]

# %%
for expr in all_feature_combinations:
    num_feats = len(expr)
    basis = ' * '.join([f'{i}**C' for i in expr])
    log_eq = 'C + ' + '+ '.join([f'C * log({var})' for var in expr])
    Cs, _ = optimize_equation(log_eq, normalize_by_iqr(X), np.log(y + 1), variables, loss='mse', initial_guess=np.ones(num_feats+1), basinhop=False)
    Cs = Cs.tolist()
    eq_intrcp = f'C + C * {basis}'
    Cs_intrcp, _ = optimize_equation(eq_intrcp, normalize_by_iqr(X), y, variables, loss='poisson', initial_guess=[-1, np.exp(Cs[0])] + Cs[1:], basinhop=False, minimizer_kwargs = {"method": "Powell"})
    # eq_linear2 = f'C + {basis}'
    # Cs2, _ = optimize_equation(eq_linear2, normalize_by_iqr(X), y, variables, loss='poisson', initial_guess=[1, Cs[0]], basinhop=False, minimizer_kwargs = {"method": "Powell"})
    eq_no_intrcp = f'C * {basis}'
    Cs_no_intrcp, _ = optimize_equation(eq_no_intrcp, normalize_by_iqr(X), y, variables, loss='poisson', initial_guess=[np.exp(Cs[0])] + Cs[1:], basinhop=False, minimizer_kwargs = {"method": "Powell"})
    
    eqs_linear = [eq_intrcp, eq_no_intrcp] 
    Cs = [Cs_intrcp, Cs_no_intrcp]
    all_metrics = []
    for eq_linear, params in zip(eqs_linear, Cs):
            equation_str_fitted = replace_optimized_parameters(eq_linear, params)
            eq = PoissonEquation(equation_str_fitted, variables)
            _, y_pred, all_params, _ = loocv(eq, X, y)
            v = metric(y, y_pred)
            print(equation_str_fitted)
            all_last_params = [params['Cs'][-1] for params in all_params]
            print(f'Mean: {np.mean(all_last_params)}, Min: {np.min(all_last_params)}, Max: {np.max(all_last_params)}, Range: {np.max(all_last_params) - np.min(all_last_params)}')
            print(v)
            all_metrics.append(v)
    # Find the index of the smallest loss
    best_index = all_metrics.index(max(all_metrics))

    # Get the corresponding C values and minimum loss
    best_eq_linear = eqs_linear[best_index]
    best_Cs = Cs[best_index]
    best_eq = replace_optimized_parameters(best_eq_linear, best_Cs)
    best_metric = all_metrics[best_index]
    res2 += [(best_eq, best_metric)]

for best_eq, best_metric in res2:
      print(f'Equation: {best_eq}, Best: {best_metric}')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[183], line 5
#       3 basis = ' * '.join([f'{i}**C' for i in expr])
#       4 log_eq = 'C + ' + '+ '.join([f'C * log({var})' for var in expr])
# ----> 5 Cs, _ = optimize_equation(log_eq, normalize_by_iqr(X), np.log(y + 1), variables, loss='mse', initial_guess=np.ones(num_feats+1), basinhop=False)
#       6 Cs = Cs.tolist()
#       7 eq_intrcp = f'C + C * {basis}'
#
# File c:\Users\marti\OneDrive\Documentos\Universidade\2024_2025\Symbolic Regression\evaluate.py:495, in optimize_equation(equation_skeleton, X, y, variables, loss, initial_guess, basinhop, use_glm, minimizer_kwargs)
#     493     result = basinhopping(compute_loss, initial_guess, minimizer_kwargs=minimizer_kwargs)
#     494 else:
# --> 495     result = minimize(compute_loss, initial_guess, **minimizer_kwargs)
#     496 return result.x, result.fun
#
# File c:\Users\marti\anaconda3\Lib\site-packages\scipy\optimize\_minimize.py:708, in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     706     res = _minimize_cg(fun, x0, args, jac, callback, **options)
#     707 elif meth == 'bfgs':
# --> 708     res = _minimize_bfgs(fun, x0, args, jac, callback, **options)
#     709 elif meth == 'newton-cg':
#     710     res = _minimize_newtoncg(fun, x0, args, jac, hess, hessp, callback,
#     711                              **options)
#
# File c:\Users\marti\anaconda3\Lib\site-packages\scipy\optimize\_optimize.py:1477, in _minimize_bfgs(fun, x0, args, jac, callback, gtol, norm, eps, maxiter, disp, return_all, finite_diff_rel_step, xrtol, c1, c2, hess_inv0, **unknown_options)
#    1474 if maxiter is None:
#    1475     maxiter = len(x0) * 200
# -> 1477 sf = _prepare_scalar_function(fun, x0, jac, args=args, epsilon=eps,
#    1478                               finite_diff_rel_step=finite_diff_rel_step)
#    1480 f = sf.fun
#    1481 myfprime = sf.grad
#
# File c:\Users\marti\anaconda3\Lib\site-packages\scipy\optimize\_optimize.py:402, in _prepare_scalar_function(fun, x0, jac, args, bounds, epsilon, finite_diff_rel_step, hess)
#     398     bounds = (-np.inf, np.inf)
#     400 # ScalarFunction caches. Reuse of fun(x) during grad
#     401 # calculation reduces overall function evaluations.
# --> 402 sf = ScalarFunction(fun, x0, args, grad, hess,
#     403                     finite_diff_rel_step, bounds, epsilon=epsilon)
#     405 return sf
#
# File c:\Users\marti\anaconda3\Lib\site-packages\scipy\optimize\_differentiable_functions.py:166, in ScalarFunction.__init__(self, fun, x0, args, grad, hess, finite_diff_rel_step, finite_diff_bounds, epsilon)
#     163     self.f = fun_wrapped(self.x)
#     165 self._update_fun_impl = update_fun
# --> 166 self._update_fun()
#     168 # Gradient evaluation
#     169 if callable(grad):
#
# File c:\Users\marti\anaconda3\Lib\site-packages\scipy\optimize\_differentiable_functions.py:262, in ScalarFunction._update_fun(self)
#     260 def _update_fun(self):
#     261     if not self.f_updated:
# --> 262         self._update_fun_impl()
#     263         self.f_updated = True
#
# File c:\Users\marti\anaconda3\Lib\site-packages\scipy\optimize\_differentiable_functions.py:163, in ScalarFunction.__init__.<locals>.update_fun()
#     162 def update_fun():
# --> 163     self.f = fun_wrapped(self.x)
#
# File c:\Users\marti\anaconda3\Lib\site-packages\scipy\optimize\_differentiable_functions.py:145, in ScalarFunction.__init__.<locals>.fun_wrapped(x)
#     141 self.nfev += 1
#     142 # Send a copy because the user may overwrite it.
#     143 # Overwriting results in undefined behaviour because
#     144 # fun(self.x) will change self.x, with the two no longer linked.
# --> 145 fx = fun(np.copy(x), *args)
#     146 # Make sure the function returns a true scalar
#     147 if not np.isscalar(fx):
#
# File c:\Users\marti\OneDrive\Documentos\Universidade\2024_2025\Symbolic Regression\evaluate.py:479, in optimize_equation.<locals>.compute_loss(params_vals)
#     477 def compute_loss(params_vals):
#     478     # try:
# --> 479         y_pred = lambdified_func(*var_columns, *params_vals)
#     481         if np.any(np.isnan(y_pred)) or np.any(np.isinf(y_pred)):
#     482             return np.inf
#
# TypeError: _lambdifygenerated() missing 1 required positional argument: 'C2'

# %% [markdown]
# Try to fit x^k, with k = \{n/2\} U \{.25, 1/3, 2/3, 4/3\}, for the 3 different ks: k=1 and the 2 k closest to the mean of the parameter fit on the whole dataset. For C^x it doesn't make sense (x is normalized anyway and integer powers don't make sense). Do it for log(x)^C as well.
#
# Next steps:
#
# 0. ~~Implement basic functionality~~
# 1. Use BFGS and jacobian w.r.t. Cs for it to be faster
# 2. After fitting the loocv with all parameters do the custom rounding using the information learned from loocv and run it again without fitting the rounded parameters
# 3. Include more variables in the current basis function
# 4. Alter step 2. to do custom rounding for {}, {var1}, {var2}, ..., {var1, var2}, ...
# 5. Include more basis functions (log and exp)
# 6. Include denominator basis function
# 7. Combine 5. and 6.. To prune the search select only ones with best $R^2$ for the next step
# 8. Combine linearly best learned basis functions and evaluate them with LOOCV then yielding a HOF that will surely crush PySR and RSRM

# %%
rsrm_df
# Out:
#     run                                  equation  complexity      train  \
# 0     1                       2.22575163521395**H           3   0.248446
# 1     1                (H + 1.5358194749129181)/D           4   0.300417
# 2     1            (H + 15.260619115027552)/(D*T)           5   0.302567
# 3     1  -1.2832712494830179*D*H - H + P + exp(H)           8   0.302024
# 4     2                                      0**T           2 -26.632335
# 5     2                       3.616659651492994/D           3   0.260948
# 6     2                0.35348059496783707*exp(H)           3   0.266456
# 7     2                 (H + 1.530966402021697)/D           4   0.291786
# 8     2                              exp(2*H - P)           4   0.296538
# 9     2                 4.759341124102596**H/P**2           7   0.303841
# 10    2                        (D + exp(H))/(D*P)           6   0.309056
# 11    2     (D + exp(1.0136348332674319*H))/(D*P)           7   0.310775
# 12    2      4.441041321554973**H/(P**2 - P + Sl)           9   0.317938
# 13    2  3.3749401522231928**H/(-H*P + P**2 + Sl)          10   0.324449
# 14    3                                    exp(D)           2  -0.771068
# 15    3                                       P/D           3   0.265018
# 16    3                0.49344712362893756*exp(H)           3   0.278678
# 17    3                    3.382870996879005**H/P           5   0.289453
# 18    3                  2.337562084695759**H - H           4   0.293669
# 19    3           (2*H)**(1.7693262386876347 - D)           5   0.321837
# 20    3     D*exp(-6.533505334589963*H**2) + H**2           9   0.329240
# 21    3  (H*(2.9724410037503888*H - P) + 1)/(D*H)           8   0.339714
# 22    4                                         H           1   0.015889
# 23    4                                       P/D           3   0.248408
# 24    4                (3.7395656123561567 - D)/D           4   0.275932
# 25    4            (2*H)**(1.731962513961698 - D)           5   0.296258
# 26    4        19.693717364610286*exp(-D + H - P)           5   0.298830
# 27    4        9.143535966078665*exp(-D + H)/P**2           8   0.312718
# 28    5                                    exp(H)           2  -0.066084
# 29    5                       2.990064878467779/D           3   0.255017
# 30    5                (H + 1.1106161667494692)/D           4   0.274142
# 31    5              (3.957080354738821 - D)**H/P           6   0.297397
# 32    5           2.304408390175294**H + D - P**D           7   0.302701
# 33    5           2.304408394562025**H + D - P**D           7   0.302701
# 34    5         1.889714827224324**H - D*H**D + H           8   0.306537
# 35    5    -D*H - D + H**2 - P + 5.43435723816292           8   0.307366
#
#          test                 skeleton     loo_r2
# 0    0.193267                     C**H   0.440199
# 1    0.254234                (H + C)/D   0.541995
# 2    0.242438            (H + C)/(D*T)   0.542808
# 3    0.225241   C*D*H - H + P + exp(H)   0.325983
# 4  -23.241700                     C**T -50.120190
# 5    0.236755                      C/D   0.491570
# 6    0.176268                 C*exp(H)   0.485240
# 7    0.223560                (H + C)/D   0.541995
# 8    0.175398             exp(C*H - P)   0.515349
# 9    0.201917                C**H/P**C   0.517117
# 10   0.255972       (D + exp(H))/(D*P)   0.601255
# 11   0.262236     (D + exp(C*H))/(D*P)   0.589707
# 12   0.135664     C**H/(P**C - P + Sl)   0.532910
# 13   0.101627  C**H/(-H*P + P**C + Sl)   0.522550
# 14  -0.998690                   exp(D)  -1.572626
# 15   0.264988                      P/D   0.493273
# 16   0.171298                 C*exp(H)   0.485240
# 17   0.197064                   C**H/P   0.508560
# 18   0.181883                 C**H - H   0.515932
# 19   0.270217           (C*H)**(C - D)   0.586215
# 20   0.130591     D*exp(C*H**C) + H**C   0.564550
# 21  -0.167940  (H*(C*H - P) + C)/(D*H)   0.401703
# 22   0.077555                        H  -0.042535
# 23   0.319040                      P/D   0.493273
# 24   0.276800                (C - D)/D   0.527921
# 25   0.370514           (C*H)**(C - D)   0.586215
# 26   0.212650        C*exp(-D + H - P)   0.510209
# 27   0.333035       C*exp(-D + H)/P**C   0.578703
# 28  -0.477078                   exp(H)  -0.086963
# 29   0.309459                      C/D   0.491570
# 30   0.354394                (H + C)/D   0.541995
# 31   0.346935             (C - D)**H/P   0.576213
# 32   0.291675          C**H + D - P**D   0.537471
# 33   0.291675          C**H + D - P**D   0.537471
# 34   0.316541        C**H - D*H**D + H   0.584294
# 35   0.333600  -D*H - D + H**C - P + C   0.581767

# %%
import sympy
# str(sympy.simplify(sympy.expand("(X+C)**3*(X-C) + log(4*X^2*(exp(2+X)))")))
# str(sympy.expand("X1 + 183.733256531987*(0.0737744726316052*X1 + 1)**2"))
# str(sympy.expand("log(C*X**2)"))
# str(sympy.expand("exp(C*X**2 - Y)"))
# str(sympy.expand_trig("tanh(C*X**2 - Y)"))
str(sympy.expand("(X-4)/(Y+5)"))
# Out:
# 'X/(Y + 5) - 4/(Y + 5)'
